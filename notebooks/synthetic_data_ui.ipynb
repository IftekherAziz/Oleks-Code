# %% [markdown]
# ## Synthetic Data Generation
# This notebook demonstrates the interactive generation and visualization of synthetic stellar data.

# %%
import sys
from pathlib import Path

project_root = Path("..").resolve()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from astro_gui.widgets import build_ui
from astro_gui.logic import setup_callbacks

setup_callbacks()
display(build_ui())
