# %% [markdown]
# ## Clustering Experiments
#
# This notebook evaluates clustering performance of the uncertainty-aware metric on synthetic stellar populations with varying noise levels and cluster configurations. Saves summary CSVs and visual diagnostics.

# %%
import sys
from pathlib import Path

project_root = Path("..").resolve()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
    
    
from core.clustering_experiments import clustering_experiments
from plots.ami_ari_plot import plot_ami_ari_vs_noise

config_path = Path("../config/experiments.yaml")
output_dir = Path("../data")

#clustering_df, noise_df = clustering_experiments(config_path, output_dir)
#clustering_df.head()

latest_summary = sorted(
    f for f in output_dir.glob("clustering_summary_*.csv")
    if "noise" not in f.name
)[-1]

plot_ami_ari_vs_noise(latest_summary, save_path="../figures/ami_ari_comparison.png")
